# %%
print("Automated Script Generation Using Transformer-Based Machine Learning Models")
# Out:
# Automated Script Generation Using Transformer-Based Machine Learning Models

# %%
# !pip install transformers datasets torch accelerate flask
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 38.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 47.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.8 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, Trainer, TrainingArguments

# %%
import json

# load dataset
with open("dataset_gpt.json",'r',encoding='utf-8') as file:
  data=json.load(file)

# printing the first few rows to see the struture
print("sample:", data[:3])
# Out:
# sample: [{'input': 'What is Machine Learning?', 'response': 'Machine Learning (ML) is a branch of Artificial Intelligence that allows systems to learn and make decisions from data without explicit programming.'}, {'input': 'Explain supervised learning.', 'response': 'Supervised learning is an ML technique where the model is trained on labeled data, meaning input-output pairs are provided for learning.'}, {'input': 'What is deep learning?', 'response': 'Deep learning is a subset of ML that uses artificial neural networks with multiple layers to extract features and learn patterns in data.'}]

# %%
from transformers import AutoTokenizer

# Load GPT-2 tokenizer
tokenizer = AutoTokenizer.from_pretrained("gpt2")

# Add a padding token to the tokenizer
tokenizer.pad_token = tokenizer.eos_token  # Use the EOS token as the padding token

# Tokenize data
tokenized_data = [
    {
        "input_ids": tokenizer(item["input"], padding="max_length", truncation=True, max_length=128)["input_ids"],
        "labels": tokenizer(item["response"], padding="max_length", truncation=True, max_length=128)["input_ids"],
    }
    for item in data
]

print("Tokenized Sample:", tokenized_data[:3])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
# !pip install datasets

# %%
from datasets import Dataset

# Convert to Hugging Face Dataset
dataset = Dataset.from_list(tokenized_data)

# Split dataset (80% train, 20% validation)
train_test_split = dataset.train_test_split(test_size=0.2)
train_dataset = train_test_split["train"]
val_dataset = train_test_split["test"]

print("Training Samples:", len(train_dataset))
print("Validation Samples:", len(val_dataset))
# Out:
# Training Samples: 68
# Validation Samples: 17

# %%
import wandb
from transformers import AutoModelForCausalLM, TrainingArguments, Trainer
import os

# **Obtain and set your wandb API key:**
# 1. Go to https://wandb.aib6bae41ea0ee5c095d3be47ccd798a7c8c2459a1/authorize
# 2. Copy the API key.
# 3. Paste the API key below, replacing "YOUR_WANDB_API_KEY"


# api key for wb b6bae41ea0ee5c095d3be47ccd798a7c8c2459a1

os.environ["WANDB_API_KEY"] = "YOUR_WANDB_API_KEY"  # Replace with your actual API key
# Re-login to wandb, potentially resolving cached credential issues:
# !wandb login --relogin  # Force re-login from the command line

# Login to wandb (this should now work with the updated environment variable)
wandb.login() # Explicitly login to wandb

# Rest of your code... (model loading, training arguments, etc.)
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# True

# %%
# warining the pad_token

from transformers import AutoModelForCausalLM, AutoTokenizer

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("gpt2")
model = AutoModelForCausalLM.from_pretrained("gpt2")

# User input
input_text = input("Ask anything: ")
input_ids = tokenizer(input_text, return_tensors="pt").input_ids

# Generate response with penalties and sampling
output = model.generate(input_ids,
                        max_length=128,
                        do_sample=True,
                        top_k=50,
                        top_p=0.95,
                        temperature=0.7,
                        repetition_penalty=1.2)

# Decode response
response = tokenizer.decode(output[0], skip_special_tokens=True)

print("User Input:", input_text)
print("Chatbot Response:", response)
# Out:
# Ask anything: what is java explain in detail?
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# User Input: what is java explain in detail?
# Chatbot Response: what is java explain in detail?
# The reason why you don't want to write this page, or at least not try it out before using the project and seeing if your results are useful. It's important that we understand each of these points first hand so people can work on how they may use them properly as well as for other things - I would also love a link back here , just remember :)

# %%
# for better response with chat gpt nano

from transformers import AutoModelForCausalLM, AutoTokenizer

# Load tokenizer and model (Upgrade to GPT-2 Large or GPT-Neo)
model_name = "gpt2-large"  # Try "EleutherAI/gpt-neo-1.3B" for better results
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Set pad token
tokenizer.pad_token = tokenizer.eos_token

# User input (Provide context for better results)
input_text = input("Ask anything: ")
inputs = tokenizer(input_text, return_tensors="pt", padding=True)

# Generate response with improved settings
output = model.generate(
    inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_length=128,
    do_sample=True,
    top_k=40,
    top_p=0.9,
    temperature=0.6,
    repetition_penalty=1.2,
    pad_token_id=tokenizer.eos_token_id
)

# Decode response
response = tokenizer.decode(output[0], skip_special_tokens=True)

print("User Input:", input_text)
print("Chatbot Response:", response)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Ask anything: what is machine learning?
# User Input: what is machine learning?
# Chatbot Response: what is machine learning?
#
# What is a machine learning algorithm?
#
# Why is this important to you?
#
# Machine learning algorithms are used by businesses and organizations for many different tasks. They can be applied in several ways, such as:
#
# Detecting fraud, spamming or malware on websites, e-commerce sites, social networks, blogs etc.
#
# Identifying trends in online activities and usage patterns.
#
# ...

# %%
# for better response with chat gpt nano

from transformers import AutoModelForCausalLM, AutoTokenizer

# Load tokenizer and model (Upgrade to GPT-2 Large or GPT-Neo)
model_name = "EleutherAI/gpt-neo-1.3B"  # Try "EleutherAI/gpt-neo-1.3B" for better results
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Set pad token
tokenizer.pad_token = tokenizer.eos_token

# User input (Provide context for better results)
input_text = input("Ask anything: ")
inputs = tokenizer(input_text, return_tensors="pt", padding=True)

# Generate response with improved settings
output = model.generate(
    inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_length=128,
    do_sample=True,
    top_k=40,
    top_p=0.9,
    temperature=0.6,
    repetition_penalty=1.2,
    pad_token_id=tokenizer.eos_token_id
)

# Decode response
response = tokenizer.decode(output[0], skip_special_tokens=True)

print("User Input:", input_text)
print("Chatbot Response:", response)
# Out:
# User Input: what is java programming?
# Chatbot Response: what is java programming?
#
# I have a question about Java programming. I have learned Java programming from a book, but I have some doubts.
#
# What is Java programming?
#
# I have learned Java programming from a book. I have read the book, but I have some doubts.
#
# What is Java programming?
#
# I have read the book, but I have some doubts.
#
# What is Java programming?
#
# I have read the book, but I have some doubts.
#
# What is Java programming?
#
# I have read the book, but I have some doubts.
#
# What is Java

# %%
# !pip install huggingface_hub transformers gradio

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from transformers import AutoModel, AutoTokenizer

model_name = "bert-base-uncased"  # Change this to your trained model name
model = AutoModel.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Save model
model.save_pretrained("my_model")
tokenizer.save_pretrained("my_model")
# Out:
# ('my_model/tokenizer_config.json',
#  'my_model/special_tokens_map.json',
#  'my_model/vocab.txt',
#  'my_model/added_tokens.json',
#  'my_model/tokenizer.json')

# %%
import os
print(os.listdir("my_model"))  # You should see 'pytorch_model.bin', 'config.json', etc.
# Out:
# ['config.json', 'vocab.txt', 'special_tokens_map.json', 'tokenizer.json', 'tokenizer_config.json', 'pytorch_model.bin']

# %%
import os

print(os.listdir("my_model"))  # List all files in the directory
# Out:
# ['config.json', 'vocab.txt', 'special_tokens_map.json', 'tokenizer.json', 'tokenizer_config.json', 'pytorch_model.bin']

# %%
# !pip install huggingface_hub

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from huggingface_hub import HfApi

repo_id = "vikas83/my-bert-model"  # Your Hugging Face repo
local_path = "my_model"  # Your saved model directory

api = HfApi()
api.upload_folder(folder_path=local_path, repo_id=repo_id, repo_type="model")

print("Model uploaded successfully! 🚀")
# Out:
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Model uploaded successfully! 🚀

# %%
from transformers import AutoModel, AutoTokenizer

model = AutoModel.from_pretrained("vikas83/my-bert-model")
tokenizer = AutoTokenizer.from_pretrained("vikas83/my-bert-model")

print("Model loaded successfully! ✅")
# Out:
# config.json:   0%|          | 0.00/658 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in load_state_dict(checkpoint_file, is_quantized, map_location, weights_only)
#     534         weights_only_kwarg = {"weights_only": weights_only}
# --> 535         return torch.load(
#     536             checkpoint_file,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1382             except pickle.UnpicklingError as e:
# -> 1383                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1384         return _legacy_load(
#
# ...

# %%
from transformers import AutoModel, AutoTokenizer

model_path = "my_model"

model = AutoModel.from_pretrained("bert-base-uncased")  # Your model type
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# Save properly
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

print("Model re-saved successfully!")
# Out:
# Model re-saved successfully!

# %%
from huggingface_hub import HfApi

repo_id = "vikas83/my-bert-model"  # Change this to your repo name
local_path = "my_model"

api = HfApi()
api.upload_folder(folder_path=local_path, repo_id=repo_id, repo_type="model")

print("Re-uploaded model successfully!")
# Out:
# Re-uploaded model successfully! 🚀

# %%
from transformers import AutoModel, AutoTokenizer

model = AutoModel.from_pretrained("vikas83/my-bert-model")
tokenizer = AutoTokenizer.from_pretrained("vikas83/my-bert-model")

print("Model loaded successfully!")
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.22k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Model loaded successfully! ✅

# %%
import gradio as gr
from transformers import AutoModel, AutoTokenizer

model_name = "vikas83/my-bert-model"  # Your uploaded model name

# Load model and tokenizer
model = AutoModel.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

def generate_response(text):
    inputs = tokenizer(text, return_tensors="pt")
    outputs = model(**inputs)
    return "Model processed successfully!"  # Modify as per your model output

# Create Gradio UI
iface = gr.Interface(
    fn=generate_response,
    inputs="text",
    outputs="text",
    title="My BERT Model",
    description="Enter text and see how the model responds!"
)

iface.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b3c02e2e4aa9370906.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b3c02e2e4aa9370906.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
